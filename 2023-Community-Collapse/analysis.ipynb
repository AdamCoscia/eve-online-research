# %% [markdown]
# # Scraping dotlan
#
# Scraping date: 12/16/2022
#
# Author: Adam Coscia <acoscia125@gmail.com>

# %% [markdown]
# # Imports and Constants

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

import json
import time

URLS = {
    "all": [
        "https://evemaps.dotlan.net/alliance/all/systems",
        "https://evemaps.dotlan.net/alliance/all/systems/page/1",
        "https://evemaps.dotlan.net/alliance/all/systems/page/2",
        "https://evemaps.dotlan.net/alliance/all/systems/page/3",
        "https://evemaps.dotlan.net/alliance/all/systems/page/4",
        "https://evemaps.dotlan.net/alliance/all/systems/page/5",
        "https://evemaps.dotlan.net/alliance/all/systems/page/6",
        "https://evemaps.dotlan.net/alliance/all/systems/page/7",
        "https://evemaps.dotlan.net/alliance/all/systems/page/8",
        "https://evemaps.dotlan.net/alliance/all/systems/page/9",
        "https://evemaps.dotlan.net/alliance/all/systems/page/10",
        "https://evemaps.dotlan.net/alliance/all/systems/page/11",
        "https://evemaps.dotlan.net/alliance/all/systems/page/12",
        "https://evemaps.dotlan.net/alliance/all/systems/page/13",
        "https://evemaps.dotlan.net/alliance/all/systems/page/14",
        "https://evemaps.dotlan.net/alliance/all/systems/page/15",
        "https://evemaps.dotlan.net/alliance/all/systems/page/16",
        "https://evemaps.dotlan.net/alliance/all/systems/page/17",
        "https://evemaps.dotlan.net/alliance/all/systems/page/18",
        "https://evemaps.dotlan.net/alliance/all/systems/page/19",
        "https://evemaps.dotlan.net/alliance/all/systems/page/20",
        "https://evemaps.dotlan.net/alliance/all/systems/page/21",
        "https://evemaps.dotlan.net/alliance/all/systems/page/22",
        "https://evemaps.dotlan.net/alliance/all/systems/page/23",
        "https://evemaps.dotlan.net/alliance/all/systems/page/24",
        "https://evemaps.dotlan.net/alliance/all/systems/page/25",
        "https://evemaps.dotlan.net/alliance/all/systems/page/26",
        "https://evemaps.dotlan.net/alliance/all/systems/page/27",
        "https://evemaps.dotlan.net/alliance/all/systems/page/28",
        "https://evemaps.dotlan.net/alliance/all/systems/page/29",
        "https://evemaps.dotlan.net/alliance/all/systems/page/30",
        "https://evemaps.dotlan.net/alliance/all/systems/page/31",
    ],
    "dead": [
        "https://evemaps.dotlan.net/alliance/dead/systems",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/1",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/2",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/3",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/4",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/5",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/6",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/7",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/8",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/9",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/10",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/11",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/12",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/13",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/14",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/15",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/16",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/17",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/18",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/19",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/20",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/21",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/22",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/23",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/24",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/25",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/26",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/27",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/28",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/29",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/30",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/31",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/32",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/33",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/34",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/35",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/36",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/37",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/38",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/39",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/40",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/41",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/42",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/43",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/44",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/45",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/46",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/47",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/48",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/49",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/50",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/51",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/52",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/53",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/54",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/55",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/56",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/57",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/58",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/59",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/60",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/61",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/62",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/63",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/64",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/65",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/66",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/67",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/68",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/69",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/70",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/71",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/72",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/73",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/74",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/75",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/76",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/77",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/78",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/79",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/80",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/81",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/82",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/83",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/84",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/85",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/86",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/87",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/88",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/89",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/90",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/91",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/92",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/93",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/94",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/95",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/96",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/97",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/98",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/99",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/100",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/101",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/102",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/103",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/104",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/105",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/106",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/107",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/108",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/109",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/110",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/111",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/112",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/113",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/114",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/115",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/116",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/117",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/118",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/119",
        "https://evemaps.dotlan.net/alliance/dead/systems/page/120",
    ],
}

# %% [markdown]
# # Collect alive/dead alliances
#
# Alive (all): <https://evemaps.dotlan.net/alliance/all>
#
# Dead: <https://evemaps.dotlan.net/alliance/dead>

# %%
# alliance_types = ["all", "dead"]
# for alliance_type in alliance_types:
#     dfs = []
#     for url in URLS[alliance_type]:
#         r = requests.get(url) # Scrape url
#         soup = BeautifulSoup(r.text, "html.parser") # parse text with bs
#         table = soup.find("table", class_="tablelist") # Find table on page
#         df_list = pd.read_html(str(table)) # Convert table string to DataFrame
#         df = df_list[0]
#         dfs.append(df)
#         time.sleep(1/10) # limit the scraping rate to x pages per second
#     df_all = pd.concat(dfs) # Combine all DataFrames
#     df_all.to_csv(f"data/alliances_{alliance_type}.csv", index=False)

# %% [markdown]
# # Collect alliance corporation information (all)
#
# For example: <https://evemaps.dotlan.net/alliance/Pan-Intergalatic_Business_Community/corporations>
#
# Stats:
#
# - 3601 alliances, ~3kb of details/record, ~1.33 records/second -> ~11MB total, ~45min total runtime
#
# Attributes:
#
# - Alliance name
# - Ticker
# - Alliance ID
# - Founded
# - Number of Members
# - Number of Corporations
# - Current corporations
#   - Name
#   - Ticker
#   - Joined
# - Former corporations
#   - Name
#   - Ticker
#   - Joined
#   - Left

# %%
# df_all = pd.read_csv("data/alliances_all.csv")
# df_all = df_all.drop(columns=["Unnamed: 0", "Unnamed: 1", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8"])

# alliances = df_all["Alliance"].to_list()
# dfs_table1 = []
# recs_table2 = []
# recs_table3 = []

# i = 0
# n = len(alliances)
# for alliance in alliances:
#     i += 1
#     print(f"{i}/{n}", end="\r")
    
#     # get tables
#     url = f"https://evemaps.dotlan.net/alliance/{alliance}/corporations"
#     r = requests.get(url) # Scrape url
#     soup = BeautifulSoup(r.text, "html.parser") # parse text with bs
#     tables = soup.find_all("table", class_="tablelist") # every page has 3 tables

#     # First table (alliance information)
#     # Columns = ['Ticker', 'Faction', 'Founded', 'AllianceID']
#     try:
#         df_list = pd.read_html(str(tables[0])) # Convert table string to DataFrame
#         df = df_list[0].set_index(0).T.drop(columns=["Name", "Members", "Corporations"])
#     except:
#         df = pd.DataFrame([[np.nan, np.nan, np.nan, np.nan]], columns=['Ticker', 'Faction', 'Founded', 'AllianceID'])
#     dfs_table1.append(df)

#     # Second table (current corporations)
#     try:
#         df_list = pd.read_html(str(tables[1])) # Convert table string to DataFrame
#         recs = df_list[0].drop(columns=["Unnamed: 0"]).to_json(orient="records")
#     except:
#         recs = []
#     recs_table2.append(recs)

#     # Third table (former corporations)
#     try:
#         df_list = pd.read_html(str(tables[2])) # Convert table string to DataFrame
#         recs = df_list[0].drop(columns=["Unnamed: 0"]).to_json(orient="records")
#     except:
#         recs = []
#     recs_table3.append(recs)

# # combine lists of objects into dataframes
# df_info = pd.concat(dfs_table1).reset_index(drop=True)
# df_current_corps = pd.DataFrame(recs_table2, columns=['Current corporations'])
# df_former_corps = pd.DataFrame(recs_table3, columns=['Former corporations'])

# # combine all the dataframes
# df_all_final = pd.concat([df_all, df_info, df_current_corps, df_former_corps], axis=1)

# # write to file
# df_all_final.to_csv("data/alliances_all_corporations.csv", index=False)

# %% [markdown]
# # Collect alliance corporation information (dead)
#
# For example: <https://evemaps.dotlan.net/alliance/-Entropy-/corporations>
#
# Stats:
#
# - 12090 alliances, ~1.5kb details/record, ~1.33 records/second -> ~20MB total, ~2.5hrs total runtime
#
# Attributes:
#
# - Alliance name
# - Ticker
# - Alliance ID
# - Founded
# - Closed
# - Former corporations
#   - Name
#   - Ticker
#   - Joined
#   - Left

# %%
# df_dead = pd.read_csv("data/alliances_dead.csv")
# df_dead = df_dead.drop(columns=["Unnamed: 0", "Unnamed: 1"])

# alliances = df_dead["Alliance"].to_list()
# dfs_table1 = []
# recs_table3 = []

# i = 0
# n = len(alliances)
# for alliance in alliances:
#     i += 1
#     print(f"{i}/{n}", end="\r")
    
#     # get tables
#     url = f"https://evemaps.dotlan.net/alliance/{alliance}/corporations"
#     r = requests.get(url) # Scrape url
#     soup = BeautifulSoup(r.text, "html.parser") # parse text with bs
#     tables = soup.find_all("table", class_="tablelist") # every page has 3 tables

#     # First table (alliance information)
#     # Columns = ['Ticker', 'Faction', 'Founded', 'Closed', 'AllianceID']
#     try:
#         df_list = pd.read_html(str(tables[0])) # Convert table string to DataFrame
#         df = df_list[0].set_index(0).T.drop(columns=["Name", "Members", "Corporations"])
#     except:
#         df = pd.DataFrame([[np.nan, np.nan, np.nan, np.nan, np.nan]], columns=['Ticker', 'Faction', 'Founded', 'Closed', 'AllianceID'])
#     dfs_table1.append(df)

#     # Third table (former corporations)
#     try:
#         df_list = pd.read_html(str(tables[2])) # Convert table string to DataFrame
#         recs = df_list[0].drop(columns=["Unnamed: 0"]).to_json(orient="records")
#     except:
#         recs = []
#     recs_table3.append(recs)

# # combine lists of objects into dataframes
# df_info = pd.concat(dfs_table1).reset_index(drop=True)
# df_former_corps = pd.DataFrame(recs_table3, columns=['Former corporations'])

# # combine all the dataframes
# df_dead_final = pd.concat([df_dead, df_info, df_former_corps], axis=1)

# # write to file
# df_dead_final.to_csv("data/alliances_dead_corporations.csv", index=False)

# %% [markdown]
# # Collect zkillboard Alltime stats (all)
#
# - 3106 alliances, ~0.1kb details/record, ~1 records/second -> ~11MB total, ~1hr total runtime
#
# For example:
#
# - <https://zkillboard.com/alliance/495729389/>
# - <https://zkillboard.com/api/stats/allianceID/495729389/>

# %%
# df_all_corps = pd.read_csv("data/alliances_all_corporations.csv")

# alliances = df_all_corps["AllianceID"].to_list()

# # scrape responsibly!!!
# headers = {
#     'Accept-Encoding': 'gzip',
#     'User-Agent': 'https://adamcoscia.github.io/ | Adam Coscia | acoscia125@gmail.com',
# }

# dfs = []
# columns = [
#     "Ships Alltime Destroyed",
#     "Ships Alltime Destroyed Rank",
#     "Ships Alltime Lost",
#     "Ships Alltime Lost Rank",
#     "Ships Alltime Efficiency",
#     "Ships Alltime Rank",
#     "Points Alltime Destroyed",
#     "Points Alltime Destroyed Rank",
#     "Points Alltime Lost",
#     "Points Alltime Lost Rank",
#     "Points Alltime Efficiency",
#     "Points Alltime Rank",
#     "ISK Alltime Destroyed",
#     "ISK Alltime Destroyed Rank",
#     "ISK Alltime Lost",
#     "ISK Alltime Lost Rank",
#     "ISK Alltime Efficiency",
#     "ISK Alltime Rank",
#     "Danger Ratio",
#     "Snuggly Ratio",
#     "Gang Ratio",
#     "Solo Ratio",
# ]

# i = 0
# n = len(alliances)
# for alliance_id in alliances:
#     i += 1
#     print(f"{i}/{n}", end="\r")
    
#     # Scrape zkillboard API
#     url_zkb_api = f"https://zkillboard.com/api/stats/allianceID/{int(alliance_id)}/"
#     while True:
#         try:
#             r = requests.get(url_zkb_api, headers=headers) # Scrape url
#             stats = json.loads(r.text)
#             break
#         except:
#             continue

#     try:
#         ships_alltime_destroyed = stats["shipsDestroyed"]
#     except:
#         ships_alltime_destroyed = 0
#     try:
#         ships_alltime_lost = stats["shipsLost"]
#     except:
#         ships_alltime_lost = 0
#     try:
#         points_alltime_destroyed = stats["pointsDestroyed"]
#     except:
#         points_alltime_destroyed = 0
#     try:
#         points_alltime_lost = stats["pointsLost"]
#     except:
#         points_alltime_lost = 0
#     try:
#         isk_alltime_destroyed = stats["iskDestroyed"]
#     except:
#         isk_alltime_destroyed = 0
#     try:
#         isk_alltime_lost = stats["iskLost"]
#     except:
#         isk_alltime_lost = 0
#     try:
#         danger_ratio = stats["dangerRatio"]
#         snuggly_ratio = 100 - danger_ratio
#     except:
#         danger_ratio = np.nan
#         snuggly_ratio = np.nan
#     try:
#         gang_ratio = stats["gangRatio"]
#         solo_ratio = 100 - gang_ratio
#     except:
#         gang_ratio = np.nan
#         solo_ratio = np.nan

#     # Scrape zkillboard directly for info not available through API
#     url_zkb = f"https://zkillboard.com/alliance/{int(alliance_id)}/"
#     while True:
#         try:
#             r = requests.get(url_zkb) # Scrape url
#             break
#         except:
#             continue

#     try:
#         soup = BeautifulSoup(r.text, "html.parser") # parse text with bs
#         rows = soup.find_all("tr", class_="alltime-ranks") # every page has 3 alltime-ranks rows
#     except:
#         rows = None # page does not exist?
    
#     # Row 1 (ships)
#     try:
#         elements = rows[0].find_all(recursive=False)
#     except:
#         elements = None  # page does not exist
#     try:
#         ships_alltime_destroyed_rank = int(elements[2].text.strip().replace(",", ""))
#     except:
#         ships_alltime_destroyed_rank = np.nan
#     try:
#         ships_alltime_lost_rank = int(elements[4].text.strip().replace(",", ""))
#     except:
#         ships_alltime_lost_rank = np.nan
#     try:
#         ships_alltime_efficiency = float(elements[5].text.strip())
#     except:
#         ships_alltime_efficiency = np.nan
#     try:
#         ships_alltime_rank = float(elements[6].text.strip().replace(",", ""))
#     except:
#         ships_alltime_rank = np.nan
    
#     # Row 2 (points)
#     try:
#         elements = rows[1].find_all(recursive=False)
#     except:
#         elements = None  # page does not exist
#     try:
#         points_alltime_destroyed_rank = int(elements[2].text.strip().replace(",", ""))
#     except:
#         points_alltime_destroyed_rank = np.nan
#     try:
#         points_alltime_lost_rank = int(elements[4].text.strip().replace(",", ""))
#     except:
#         points_alltime_lost_rank = np.nan
#     try:
#         points_alltime_efficiency = float(elements[5].text.strip())
#     except:
#         points_alltime_efficiency = np.nan
#     try:
#         points_alltime_rank = float(elements[6].text.strip().replace(",", ""))
#     except:
#         points_alltime_rank = np.nan

#     # Row 3 (isk)
#     try:
#         elements = rows[2].find_all(recursive=False)
#     except:
#         elements = None  # page does not exist
#     try:
#         isk_alltime_destroyed_rank = int(elements[2].text.strip().replace(",", ""))
#     except:
#         isk_alltime_destroyed_rank = np.nan
#     try:
#         isk_alltime_lost_rank = int(elements[4].text.strip().replace(",", ""))
#     except:
#         isk_alltime_lost_rank = np.nan
#     try:
#         isk_alltime_efficiency = float(elements[5].text.strip())
#     except:
#         isk_alltime_efficiency = np.nan
#     try:
#         isk_alltime_rank = float(elements[6].text.strip().replace(",", ""))
#     except:
#         isk_alltime_rank = np.nan

#     # Combine stats into single row/DataFrame
#     row = [
#         ships_alltime_destroyed,
#         ships_alltime_destroyed_rank,
#         ships_alltime_lost,
#         ships_alltime_lost_rank,
#         ships_alltime_efficiency,
#         ships_alltime_rank,
#         points_alltime_destroyed,
#         points_alltime_destroyed_rank,
#         points_alltime_lost,
#         points_alltime_lost_rank,
#         points_alltime_efficiency,
#         points_alltime_rank,
#         isk_alltime_destroyed,
#         isk_alltime_destroyed_rank,
#         isk_alltime_lost,
#         isk_alltime_lost_rank,
#         isk_alltime_efficiency,
#         isk_alltime_rank,
#         danger_ratio,
#         snuggly_ratio,
#         gang_ratio,
#         solo_ratio
#     ]
#     df = pd.DataFrame([row], columns=columns)
#     dfs.append(df)
    
#     # limit the rate to the same domain by 1s
#     time.sleep(1)

# # combine lists of objects into dataframes
# df_stats = pd.concat(dfs).reset_index(drop=True)

# # combine all the dataframes and reorder columns
# df_all_corps_stats = pd.concat([df_all_corps, df_stats], axis=1)
# cols = df_all_corps_stats.columns.tolist()
# cols.append(cols.pop(cols.index('Current corporations')))
# cols.append(cols.pop(cols.index('Former corporations')))
# df_all_corps_stats = df_all_corps_stats[cols]

# # write to file
# df_all_corps_stats.to_csv("data/alliances_all_corporations_stats.csv", index=False)

# df_all_corps_stats

# %% [markdown]
# # Collect zkillboard Alltime stats (dead)
#
# - 12090 alliances, ~0.1kb details/record, ~1 records/second -> ~21MB total, ~3.5hr total runtime
#
# For example:
#
# - <https://zkillboard.com/alliance/495729389/>
# - <https://zkillboard.com/api/stats/allianceID/495729389/>

# %%
# df_dead_corps = pd.read_csv("data/alliances_dead_corporations.csv")

# alliances = df_dead_corps["AllianceID"].to_list()

# # scrape responsibly!!!
# headers = {
#     'Accept-Encoding': 'gzip',
#     'User-Agent': 'https://adamcoscia.github.io/ | Adam Coscia | acoscia125@gmail.com',
# }

# dfs = []
# columns = [
#     "Ships Alltime Destroyed",
#     "Ships Alltime Destroyed Rank",
#     "Ships Alltime Lost",
#     "Ships Alltime Lost Rank",
#     "Ships Alltime Efficiency",
#     "Ships Alltime Rank",
#     "Points Alltime Destroyed",
#     "Points Alltime Destroyed Rank",
#     "Points Alltime Lost",
#     "Points Alltime Lost Rank",
#     "Points Alltime Efficiency",
#     "Points Alltime Rank",
#     "ISK Alltime Destroyed",
#     "ISK Alltime Destroyed Rank",
#     "ISK Alltime Lost",
#     "ISK Alltime Lost Rank",
#     "ISK Alltime Efficiency",
#     "ISK Alltime Rank",
#     "Danger Ratio",
#     "Snuggly Ratio",
#     "Gang Ratio",
#     "Solo Ratio",
# ]

# i = 0
# n = len(alliances)
# for alliance_id in alliances:
#     i += 1
#     print(f"{i}/{n}", end="\r")
    
#     # Scrape zkillboard API
#     try:
#         url_zkb_api = f"https://zkillboard.com/api/stats/allianceID/{int(alliance_id)}/"
#         while True:
#             try:
#                 r = requests.get(url_zkb_api, headers=headers) # Scrape url
#                 stats = json.loads(r.text)
#                 break
#             except:
#                 continue
#     except:
#         stats = None # alliance_id may be None or NaN

#     try:
#         ships_alltime_destroyed = stats["shipsDestroyed"]
#     except:
#         ships_alltime_destroyed = 0
#     try:
#         ships_alltime_lost = stats["shipsLost"]
#     except:
#         ships_alltime_lost = 0
#     try:
#         points_alltime_destroyed = stats["pointsDestroyed"]
#     except:
#         points_alltime_destroyed = 0
#     try:
#         points_alltime_lost = stats["pointsLost"]
#     except:
#         points_alltime_lost = 0
#     try:
#         isk_alltime_destroyed = stats["iskDestroyed"]
#     except:
#         isk_alltime_destroyed = 0
#     try:
#         isk_alltime_lost = stats["iskLost"]
#     except:
#         isk_alltime_lost = 0
#     try:
#         danger_ratio = stats["dangerRatio"]
#         snuggly_ratio = 100 - danger_ratio
#     except:
#         danger_ratio = np.nan
#         snuggly_ratio = np.nan
#     try:
#         gang_ratio = stats["gangRatio"]
#         solo_ratio = 100 - gang_ratio
#     except:
#         gang_ratio = np.nan
#         solo_ratio = np.nan

#     # Scrape zkillboard directly for info not available through API
#     try:
#         url_zkb = f"https://zkillboard.com/alliance/{int(alliance_id)}/"
#         while True:
#             try:
#                 r = requests.get(url_zkb) # Scrape url
#                 break
#             except:
#                 continue
#     except:
#         r = None # alliance_id may be None or NaN

#     try:
#         soup = BeautifulSoup(r.text, "html.parser") # parse text with bs
#         rows = soup.find_all("tr", class_="alltime-ranks") # every page has 3 alltime-ranks rows
#     except:
#         rows = None # page does not exist?
    
#     # Row 1 (ships)
#     try:
#         elements = rows[0].find_all(recursive=False)
#     except:
#         elements = None  # page does not exist
#     try:
#         ships_alltime_destroyed_rank = int(elements[2].text.strip().replace(",", ""))
#     except:
#         ships_alltime_destroyed_rank = np.nan
#     try:
#         ships_alltime_lost_rank = int(elements[4].text.strip().replace(",", ""))
#     except:
#         ships_alltime_lost_rank = np.nan
#     try:
#         ships_alltime_efficiency = float(elements[5].text.strip())
#     except:
#         ships_alltime_efficiency = np.nan
#     try:
#         ships_alltime_rank = float(elements[6].text.strip().replace(",", ""))
#     except:
#         ships_alltime_rank = np.nan
    
#     # Row 2 (points)
#     try:
#         elements = rows[1].find_all(recursive=False)
#     except:
#         elements = None  # page does not exist
#     try:
#         points_alltime_destroyed_rank = int(elements[2].text.strip().replace(",", ""))
#     except:
#         points_alltime_destroyed_rank = np.nan
#     try:
#         points_alltime_lost_rank = int(elements[4].text.strip().replace(",", ""))
#     except:
#         points_alltime_lost_rank = np.nan
#     try:
#         points_alltime_efficiency = float(elements[5].text.strip())
#     except:
#         points_alltime_efficiency = np.nan
#     try:
#         points_alltime_rank = float(elements[6].text.strip().replace(",", ""))
#     except:
#         points_alltime_rank = np.nan

#     # Row 3 (isk)
#     try:
#         elements = rows[2].find_all(recursive=False)
#     except:
#         elements = None  # page does not exist
#     try:
#         isk_alltime_destroyed_rank = int(elements[2].text.strip().replace(",", ""))
#     except:
#         isk_alltime_destroyed_rank = np.nan
#     try:
#         isk_alltime_lost_rank = int(elements[4].text.strip().replace(",", ""))
#     except:
#         isk_alltime_lost_rank = np.nan
#     try:
#         isk_alltime_efficiency = float(elements[5].text.strip())
#     except:
#         isk_alltime_efficiency = np.nan
#     try:
#         isk_alltime_rank = float(elements[6].text.strip().replace(",", ""))
#     except:
#         isk_alltime_rank = np.nan

#     # Combine stats into single row/DataFrame
#     row = [
#         ships_alltime_destroyed,
#         ships_alltime_destroyed_rank,
#         ships_alltime_lost,
#         ships_alltime_lost_rank,
#         ships_alltime_efficiency,
#         ships_alltime_rank,
#         points_alltime_destroyed,
#         points_alltime_destroyed_rank,
#         points_alltime_lost,
#         points_alltime_lost_rank,
#         points_alltime_efficiency,
#         points_alltime_rank,
#         isk_alltime_destroyed,
#         isk_alltime_destroyed_rank,
#         isk_alltime_lost,
#         isk_alltime_lost_rank,
#         isk_alltime_efficiency,
#         isk_alltime_rank,
#         danger_ratio,
#         snuggly_ratio,
#         gang_ratio,
#         solo_ratio
#     ]
#     df = pd.DataFrame([row], columns=columns)
#     dfs.append(df)
    
#     # limit the rate to the same domain by 1s
#     time.sleep(1)

# # combine lists of objects into dataframes
# df_stats = pd.concat(dfs).reset_index(drop=True)

# # combine all the dataframes and reorder columns
# df_dead_corps_stats = pd.concat([df_dead_corps, df_stats], axis=1)
# cols = df_dead_corps_stats.columns.tolist()
# cols.append(cols.pop(cols.index('Former corporations')))
# df_dead_corps_stats = df_dead_corps_stats[cols]

# # write to file
# df_dead_corps_stats.to_csv("data/alliances_dead_corporations_stats.csv", index=False)

# df_dead_corps_stats

# %% [markdown]
# # Post-processing
#
# - Remove alliances where `Closed` attribute is not NaN (about 10 rows)

# %%
df = pd.read_csv("data/alliances_dead_corporations_stats.csv")
# df = pd.read_csv("data/alliances_dead_corporations_stats.csv")

df.iloc[0]

# alliances = df_all_corps["AllianceID"].to_list()

# df.dropna(subset=["Closed"])

# Unpack nested data
# df["Current corporations"].apply(json.loads).explode().apply(pd.Series)
# df["Former corporations"].apply(json.loads).explode().apply(pd.Series)
# Out:
# Alliance                                                                 -Entropy-
# Systems                                                                          0
# Members                                                                          0
# Corps                                                                            0
# Ticker                                                                         ENT
# Faction                                                                          -
# Founded                                                                 2011-12-05
# Closed                                                                  2017-11-05
# AllianceID                                                              99001432.0
# Ships Alltime Destroyed                                                       1002
# Ships Alltime Destroyed Rank                                                3126.0
# ...
